# %% [markdown]
# **Name- Rucha Ratnaparkhi**
#
# **Level- Beginner**
#
# **Task 4- Image to Pencil Sketch with Python**

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
image = cv2.imread("/content/monument.jpg")

# %%
img = cv2.resize(image,(600,500))

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x500 at 0x7F2CB79EC610>

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=600x500 at 0x7F2CB79EF690>

# %%
img_invert = cv2.bitwise_not(img_gray)
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=600x500 at 0x7F2CB79F5290>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21,21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=600x500 at 0x7F2CB92D4950>

# %%
def dodgeV2(x, y):
  return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dodgeV2(img_gray, img_smoothing)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=600x500 at 0x7F2CB9262E10>

# %%
cv2_imshow(img)
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x500 at 0x7F2CB79EFE50>
# <PIL.Image.Image image mode=L size=600x500 at 0x7F2CB79EFD90>

# %% [markdown]
# # **Thankyou**
